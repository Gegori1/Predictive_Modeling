# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/energydata_complete.csv')

# %% [markdown]
# ### Dat inspection and processing

# %%
# df.info()

# %%
data = (
    df
    .drop(['date', 'rv1', 'rv2'], axis=1)
    .assign(target = lambda k: k.lights + k.Appliances)
    .drop(['lights', 'Appliances'], axis=1)
)

# %%
# data.info()

# %%
# create a function to check for inf values
check_inf = lambda df: df[~df.map(np.isreal).all(1)]
check_inf(data)

# %%
# sns.pairplot(data)
# From what can be seen in the pairplot, there is no correlation between the target and the other variables and some independant variables are somehow correlated
# All variables except for RH6 look like they are normally distributed, RH6 looks like it has a bimodal distribution
# I will normalize every variable
# The target variable is very skewed. I will try to normalize it by taking the log of it
# I will also try to normalize it by taking the square root of it
# I will apply LDA to the data and see if it imporves.

# %%
data.corr().abs().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_736e6_row0_col0, #T_736e6_row1_col1, #T_736e6_row2_col2, #T_736e6_row3_col3, #T_736e6_row4_col4, #T_736e6_row5_col5, #T_736e6_row6_col6, #T_736e6_row7_col7, #T_736e6_row8_col8, #T_736e6_row9_col9, #T_736e6_row10_col10, #T_736e6_row11_col11, #T_736e6_row12_col12, #T_736e6_row13_col13, #T_736e6_row14_col14, #T_736e6_row15_col15, #T_736e6_row16_col16, #T_736e6_row17_col17, #T_736e6_row18_col18, #T_736e6_row19_col19, #T_736e6_row20_col20, #T_736e6_row21_col21, #T_736e6_row22_col22, #T_736e6_row23_col23, #T_736e6_row24_col24 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_736e6_row0_col1, #T_736e6_row21_col20 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_736e6_row0_col2, #T_736e6_row5_col13, #T_736e6_row13_col5, #T_736e6_row17_col5 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# ...

# %%
# There are some very correlated variables, I will try to remove them
